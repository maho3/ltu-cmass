# %% [markdown]
# # preprocess.ipynb
# Scratch notebook to provide general supporting datasets/analysis to make the main pipeline faster.

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from tqdm import tqdm
from os.path import join as pjoin
from tools.freecode import load_quijote_halos, TruncatedPowerLaw

# %% [markdown]
# ## Fit halo bias quijote
# Fit the parameters of a Truncated Power Law to connect the voxelized density field to the halo counts. Use the Quijote 1 Gpc/h simulations, at various cosmologies and mass bins.

# %%
def load_hhalos(snapdir):
    # load quijote halos and compute histogram
    pos_h, mass, _, _ = load_quijote_halos(snapdir)
    posm = np.concatenate([pos_h, np.log10(mass)[:, None]], axis=1)
    h, edges = np.histogramdd(
        posm,
        (128, 128, 128, 10),
        range=[(0, 1e3)]*3+[(12.8, 15.8)]
    )
    return h, edges

# %%
lhid=3

load_dir = f'/home/mattho/git/cmass-ili/data/quijote/source/density_field/latin_hypercube/{lhid}'
rho1g = np.load(pjoin(load_dir, 'df_m_128_z=0.npy'))
load_dir = f'/home/mattho/git/cmass-ili/data/quijote/source/Halos/latin_hypercube/{lhid}'
hhalos1g, edges = load_hhalos(load_dir)

# %%
law = TruncatedPowerLaw()
def load_bias_params(bias_path, lhid):
    # load the bias parameters for using the 1 Gpc Quijote sims
    popt = np.load(pjoin(bias_path, f'{lhid}.npy'))
    medges = np.load(pjoin(bias_path, 'medges.npy'))
    return popt, medges
bias_path = pjoin('data', 'quijote/bias_fit/LH_n=128')
popt, medges = load_bias_params(bias_path, lhid)

# %%
nmean = np.zeros_like(hhalos1g)
for i in range(10):
    nmean[...,i] = law.sample(rho1g, popt[i])

# %%
f = plt.figure(figsize=(16,8))
gs = mpl.gridspec.GridSpec(2,5)

for i in range(10):
    ax = f.add_subplot(gs[i//5, i%5])
    ax.plot(rho1g.flatten(), hhalos1g[...,i].flatten(),'.', label='true', alpha=0.2)
    ax.plot(rho1g.flatten(), nmean[...,i].flatten(),'.', label='sample', alpha=0.2)
    ax.set_xlabel('rho/rhom : density contrast')
    ax.set_ylabel('halo_count')
    ax.set_ylim(-0.1,6.1)

# %%
rholin = 10**np.linspace(np.log10(rho1g.min()+1), np.log10(rho1g.max()+1), 100)-1

f = plt.figure(figsize=(7,7))
plt.loglog()
for i in range(10):
    ngal_mean = law.predict(rholin, popt[i])
    plt.plot(rholin+1, ngal_mean, label=f"[{medges[i]:.2f}, {medges[i+1]:.2f}]")
    
plt.legend(title='logM')
plt.xlabel('rho/rhom : density contrast')
plt.ylabel('ngal_mean')
# Out:
# Text(0, 0.5, 'ngal_mean')

# %% [markdown]
# TODO:
#  * compare Pk
#  * calculate cross-correlation

# %% [markdown]
# ## Calculate cmass n(z)
# Calculate the redshift distribution of cmass, which we'll use to match our mocks to.

# %%
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np
import pandas as pd
from tqdm import tqdm

import matplotlib as mpl
import matplotlib.pyplot as plt

import astropy
from astropy.io import fits
from astropy.stats import scott_bin_width

from scipy.interpolate import InterpolatedUnivariateSpline

import pymangle
from os.path import join as pjoin

# %%
import nbodykit.lab as nblab
from nbodykit import cosmology

cosmo = cosmology.Cosmology()
from tools.BOSS_FM import BOSS_angular, BOSS_veto, BOSS_redshift, thetahod_literature

# %%
def load_galaxies(fname, fields):
    with fits.open(fname) as hdul:
        gals = np.array([hdul[1].data[x] for x in fields]).T
        gals = pd.DataFrame(gals, columns=fields)    
    return gals
# load data
fname = 'data/obs/galaxy_DR12v5_CMASSLOWZTOT_North.fits'
fields = ['RA','DEC','Z',
          'WEIGHT_SYSTOT','WEIGHT_NOZ','WEIGHT_CP']
cmass = load_galaxies(fname, fields)

# %%
# apply selection and calculate area
mask = BOSS_angular(cmass['RA'], cmass['DEC'])
mask *= BOSS_redshift(cmass['Z'])
cmass = cmass[mask].reset_index(drop=True)

# %%
cmass['Z'].values
# Out:
# array([0.46564791, 0.56580216, 0.61221063, ..., 0.44704831, 0.40994021,
#        0.415804  ])

# %%
_, be = scott_bin_width(cmass['Z'].values, True)
h, _, _ = plt.hist(cmass['Z'], be, histtype='step')
plt.xlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
savepath = 'data/obs/n-z_DR12v5_CMASS_North.npy'
np.save(savepath,{'be':be, 'h':h})

# %% [markdown]
# ## Premask randoms
# Load the randoms catalog and apply the CMASS survey mask, so that we don't have to do so later on.

# %%
from gals_to_summaries.calc_Pk_nbkit import load_randoms

randoms = load_randoms()
# Out:
# badfield_mask_postprocess_pixs8.ply
# badfield_mask_unphot_seeing_extinction_pixs8_dr12.ply
# allsky_bright_star_mask_pix.ply
# bright_object_mask_rykoff_pix.ply
# centerpost_mask_dr12.ply
# collision_priority_mask_dr12.ply

# %%
savepath = pjoin('data', 'obs', 'random0_DR12v5_CMASS_North_PRECOMPUTED.npy')
np.save(savepath, randoms)

# %% [markdown]
# ## Calculate observed P(k)
# Calculate and save the power spectrum of the real CMASS data, for easy comparison with the mocks.

# %%
# %load_ext autoreload
# %autoreload 2

import os
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

from astropy.io import fits

import pymangle
from os.path import join as pjoin
from gals_to_summaries.calc_Pk_nbkit import load_randoms_precomputed, compute_Pk

import nbodykit.lab as nblab
from nbodykit import cosmology

cosmo = cosmology.Cosmology()
from tools.BOSS_FM import BOSS_angular, BOSS_veto, BOSS_redshift

# %%
# load survey
def load_galaxies(fname, fields):
    with fits.open(fname) as hdul:
        gals = np.array([hdul[1].data[x] for x in fields]).T
        gals = pd.DataFrame(gals, columns=fields)    
    return gals
# load data
fname = 'data/obs/galaxy_DR12v5_CMASSLOWZTOT_North.fits'
fields = ['RA','DEC','Z',
          'WEIGHT_SYSTOT','WEIGHT_NOZ','WEIGHT_CP']
cmass = load_galaxies(fname, fields)
mask = BOSS_angular(cmass['RA'], cmass['DEC'])
mask *= BOSS_redshift(cmass['Z'])
mask *= ~(BOSS_veto(cmass['RA'], cmass['DEC'], verbose=True))
cmass = cmass[mask].reset_index(drop=True)

crdz = np.stack([cmass['RA'], cmass['DEC'], cmass['Z']], axis=-1)
w_g = np.array(cmass['WEIGHT_SYSTOT'] * (cmass['WEIGHT_NOZ'] + cmass['WEIGHT_CP'] - 1.0))
# Out:
# badfield_mask_postprocess_pixs8.ply
# badfield_mask_unphot_seeing_extinction_pixs8_dr12.ply
# allsky_bright_star_mask_pix.ply
# bright_object_mask_rykoff_pix.ply
# centerpost_mask_dr12.ply
# collision_priority_mask_dr12.ply

# %%
randoms = load_randoms_precomputed()
cosmo = cosmology.Planck15

# compute P(k)
k_gal, p0k_gal, p2k_gal, p4k_gal = compute_Pk(crdz, randoms, cosmo, weights=w_g)

# save results
source_dir = 'data/obs'
outpath = pjoin(source_dir, 'Pk', 'Pk.npz')
np.savez(outpath, k_gal=k_gal, p0k_gal=p0k_gal,
            p2k_gal=p2k_gal, p4k_gal=p4k_gal)
# Out:
# /home/mattho/git/nbodykit/nbodykit/algorithms/convpower/fkp.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   xgrid = [xx.astype('f8') + offset[ii] for ii, xx in enumerate(density2.slabs.optx)]
# /home/mattho/git/nbodykit/nbodykit/algorithms/convpower/fkp.py:536: ComplexWarning: Casting complex values to real discards the imaginary part
#   kgrid = [kk.astype('f8') for kk in cfield.slabs.optx]

# %%
# plot all Pk
fig, axs = plt.subplots(1,3, figsize=(18,6))

axs[0].loglog()
axs[0].plot(k_gal, p0k_gal, label='galaxy')
axs[0].set_xlim([3e-3, 1.])
axs[0].set_ylim(1e2, 1e6)
axs[0].set_xlabel('$k$', fontsize=12)

axs[1].loglog()
axs[1].plot(k_gal, p2k_gal, label='galaxy')
axs[1].set_xlim([3e-3, 1.])
axs[1].set_ylim(1e2, 1e6)
axs[1].set_xlabel('$k$', fontsize=12)

axs[2].loglog()
axs[2].plot(k_gal, p4k_gal, label='galaxy')
axs[2].set_xlim([3e-3, 1.])
axs[2].set_ylim(1e2, 1e6)
axs[2].set_xlabel('$k$', fontsize=12)
# Out:
# Text(0.5, 0, '$k$')

# %% [markdown]
# ## Move Observables to simdir

# %%
from os.path import join
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from astropy.io import fits
from cmass.survey.tools import BOSS_angular, BOSS_veto, BOSS_redshift, BOSS_fiber

# %%
# load survey
def load_galaxies(fname, fields):
    with fits.open(fname) as hdul:
        gals = np.array([hdul[1].data[x] for x in fields]).T
        gals = pd.DataFrame(gals, columns=fields)    
    return gals
# load data
fname = '../data/obs/galaxy_DR12v5_CMASSLOWZTOT_North.fits'
fields = ['RA','DEC','Z',
          'WEIGHT_SYSTOT','WEIGHT_NOZ','WEIGHT_CP']
cmass = load_galaxies(fname, fields)
cmass
# Out:
#                 RA        DEC         Z  WEIGHT_SYSTOT  WEIGHT_NOZ  WEIGHT_CP
# 0       195.071285  -0.590771  0.465648       0.997614         1.0        1.0
# 1       195.022992  -0.610999  0.565802       1.006011         1.0        1.0
# 2       195.079741   0.348981  0.612211       0.972005         1.0        1.0
# 3       195.170574   0.359864  0.502060       0.992697         1.0        1.0
# 4       195.204289   0.347267  0.559173       0.972478         1.0        1.0
# ...            ...        ...       ...            ...         ...        ...
# 953250  185.876357  39.962788  0.282012       0.912746         1.0        1.0
# 953251  185.527999  40.365465  0.306736       0.944241         1.0        1.0
# 953252  185.452168  40.311640  0.415804       0.965969         1.0        1.0
# 953253  185.769923  40.282724  0.307881       0.980376         1.0        1.0
# 953254  185.730921  40.337385  0.308149       0.976697         1.0        1.0
#
# [953255 rows x 6 columns]

# %%
mask = BOSS_angular(cmass['RA'], cmass['DEC'], wdir='../data')
mask *= BOSS_redshift(cmass['Z'])
mask *= ~(BOSS_veto(cmass['RA'], cmass['DEC'], verbose=True, wdir='../data'))
cmass = cmass[mask].reset_index(drop=True)
mask = BOSS_fiber(cmass['RA'], cmass['DEC'], mode=1)
cmass = cmass[mask].reset_index(drop=True)

crdz = np.stack([cmass['RA'], cmass['DEC'], cmass['Z']], axis=-1)
w_g = np.array(cmass['WEIGHT_SYSTOT'] * (cmass['WEIGHT_NOZ'] + cmass['WEIGHT_CP'] - 1.0))
# Out:
# badfield_mask_postprocess_pixs8.ply
# badfield_mask_unphot_seeing_extinction_pixs8_dr12.ply
# allsky_bright_star_mask_pix.ply
# bright_object_mask_rykoff_pix.ply
# centerpost_mask_dr12.ply
# collision_priority_mask_dr12.ply

# %%
f, axs = plt.subplots(2,1, figsize=(8,10), gridspec_kw={'height_ratios': [1,0.3]})
axs[0].plot(crdz[:,0], crdz[:,1], ',', alpha=0.1)
axs[1].hist(crdz[:,2], bins=100, histtype='step');

# %%
outdir = '../data/cmass_ngc/L0-N0/real/obs/'
np.save(join(outdir, 'rdz0.npy'), crdz)
np.save(join(outdir, 'rdz0_survey_weight.npy'), w_g)

# %% [markdown]
# ## add more LH parameters

# %%
import pandas as pd
import numpy as np
import math

df = pd.read_csv('latin_hypercube_params.txt', sep=' ', header=None)
df.shape
# Out:
# (2000, 5)

# %%
fid = [0.3175, 0.049, 0.6711, 0.9624, 0.834]
df.loc[2000] = fid

# %%
dmin, dmax = df.min(axis=0).values, df.max(axis=0).values
Nsamp = 10

dOm = np.linspace(dmin[0], dmax[0], Nsamp+1)
toadd = [[round(dOm[i],10)] + fid[1:] for i in range(Nsamp+1)]
df = pd.concat([df, pd.DataFrame(toadd, columns=df.columns)], ignore_index=True)

ds8 = np.linspace(dmin[-1], dmax[-1], Nsamp+1)
toadd = [fid[:-1] + [round(ds8[i],10)] for i in range(Nsamp+1)]
df = pd.concat([df, pd.DataFrame(toadd, columns=df.columns)], ignore_index=True)

# %%
df.astype('float32').to_csv('latin_hypercube_params_bonus.txt', sep=' ', header=None, index=False)

# %%
# find closest point
(df - fid).abs().sum(axis=1).idxmin()
# Out:
# 663

# %%
df.loc[663,:]-fid
# Out:
# 0    0.00480
# 1   -0.00275
# 2    0.03040
# 3   -0.00170
# 4   -0.00290
# Name: 663, dtype: float64

# %% [markdown]
# ## creating shared initial white noise fields

# %%
import os
import numpy as np
import tqdm
from os.path import join as pjoin

def gen_ICs(N, seed=None):
    """Generate ICs in Fourier space."""
    if seed is not None:
        np.random.seed(seed)
    ic = np.fft.rfftn(np.random.randn(N, N, N), norm='ortho') #  / N ** (1.5)
    return ic

N = 384
ic = gen_ICs(N)

# %%
savedir = f'../data/wn/N{N}'
os.makedirs(savedir, exist_ok=True)

for i in tqdm.tqdm(range(10)):
    ic = gen_ICs(N, seed=i)
    
    savepath = pjoin(savedir, f'wn_{i}.dat')
    ic.tofile(savepath)
# Out:
# 100%|██████████| 10/10 [00:42<00:00,  4.22s/it]

# %%
with open(savepath, 'rb') as f:
    x = np.fromfile(f, np.complex128, -1)

# %%
x.shape
# Out:
# (28459008,)

# %% [markdown]
# ## Scratch

# %%
import numpy as np
import jax
from cuboid_remap import remap_Lbox

# %%
Lbox = 3000
u1, u2, u3 = (1, 1, 0), (0, 0, 1), (1, 0, 0)

np.array(remap_Lbox(u1, u2, u3))*Lbox
# Out:
# array([4242.64068712, 3000.        , 2121.32034356])

# %%
(df.iloc[:100]-fid).iloc[:,[0,-1]].abs().sum(axis=1).idxmin()
# Out:
# 53

# %%
fid
# Out:
# [0.3175, 0.049, 0.6711, 0.9624, 0.834]
